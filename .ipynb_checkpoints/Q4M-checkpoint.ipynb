# %%
from qiskit import *
from qiskit.tools.visualization import plot_bloch_multivector

# %%
circ = QuantumCircuit(1,1)
circ.x(0)

# %%
simulator = Aer.get_backend('statevector_simulator')

# %%
result = execute(circ, backend = simulator).result()

# %%
statevector = result.get_statevector()

# %%
 print(statevector)
# Out:
# [0.+0.j 1.+0.j]

# %%
from matplotlib import *

# %%
circ.draw(output='mpl')

# %%
plot_bloch_multivector(statevector)

# %%
circ.measure([0],[0])
circ.draw(output='mpl')

# %%
simulatorCounts = Aer.get_backend('qasm_simulator')
resultCounts = execute(circ, backend = simulatorCounts, shots = 1024).result()
count = resultCounts.get_counts()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(count)

# %%
# Esto de abajo muestra la matriz de el circuito ejecutado

# %%
circuit = QuantumCircuit(1,1)
circuit.x(0)
simulator = Aer.get_backend('unitary_simulator')

# %%
result = execute(circuit, backend = simulator).result()

# %%
unitary = result.get_unitary()
print(unitary)
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]
