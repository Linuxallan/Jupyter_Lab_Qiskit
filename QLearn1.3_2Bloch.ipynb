# %%
from qiskit.tools.visualization import plot_bloch_vector
from math import * #import 'pi' y otros.

# %%
# Theta, Pi, Radio
# estado |0>
coords = [pi*0,0,1]
plot_bloch_vector(coords)

# %%
# estado |1>
# no lo seee
coords = [1,1,1]
plot_bloch_vector(coords)
